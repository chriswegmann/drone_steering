# %% [markdown]
# # Gesture Detection Model

# %% [markdown]
# ## 1 Engineer features

# %% [markdown]
# ### 1.1 Import libraries and transformers

# %%
import numpy as np
import pandas as pd
import warnings
import matplotlib.pyplot as plt
from keras.utils import to_categorical
warnings.filterwarnings("ignore")
# Out:
# Using TensorFlow backend.

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Christian\\git\\drone_steering\\models'

# %%
os.chdir('..')

# %%
from app_local.module import DataEnsembler, LabelGenerator, GestureTransformer

# %% [markdown]
# ### 1.2  Load data

# %%
de = DataEnsembler(ms_per_frame=120)
de.investigate_available_datafiles(data_dir='data/gesture/', is_frame_based = True)
de.combined_data_files_df
# Out:
#                 filename_features                    filename_labels
# 0      features_flip_c_01_120.csv     labels_flip_c_01_per_frame.csv
# 1      features_flip_c_02_120.csv     labels_flip_c_02_per_frame.csv
# 2      features_flip_c_03_120.csv     labels_flip_c_03_per_frame.csv
# 3      features_flip_l_01_120.csv     labels_flip_l_01_per_frame.csv
# 4      features_flip_l_02_120.csv     labels_flip_l_02_per_frame.csv
# 5      features_flip_l_03_120.csv     labels_flip_l_03_per_frame.csv
# 6      features_flip_p_01_120.csv     labels_flip_p_01_per_frame.csv
# 7      features_land_c_01_120.csv     labels_land_c_01_per_frame.csv
# 8      features_land_c_02_120.csv     labels_land_c_02_per_frame.csv
# 9      features_land_c_03_120.csv     labels_land_c_03_per_frame.csv
# 10     features_land_l_01_120.csv     labels_land_l_01_per_frame.csv
# 11     features_land_l_02_120.csv     labels_land_l_02_per_frame.csv
# 12     features_land_l_03_120.csv     labels_land_l_03_per_frame.csv
# 13     features_move_c_01_120.csv     labels_move_c_01_per_frame.csv
# 14     features_move_l_01_120.csv     labels_move_l_01_per_frame.csv
# 15     features_move_p_01_120.csv     labels_move_p_01_per_frame.csv
# 16     features_none_p_01_120.csv                    labels_none.csv
# 17  features_takeoff_c_01_120.csv  labels_takeoff_c_01_per_frame.csv
# 18  features_takeoff_c_02_120.csv  labels_takeoff_c_02_per_frame.csv
# 19  features_takeoff_c_03_120.csv  labels_takeoff_c_03_per_frame.csv
# 20  features_takeoff_l_01_120.csv  labels_takeoff_l_01_per_frame.csv
# 21  features_takeoff_l_02_120.csv  labels_takeoff_l_02_per_frame.csv
# 22  features_takeoff_l_03_120.csv  labels_takeoff_l_03_per_frame.csv

# %%
de.load_data()
de.assemble_data(max_error=500, tolerance_range= 600)
de.display_information()
# Out:
# i: 0 	shape X: (537, 17, 16) 	shape y: (537,) 	count: 55
# i: 1 	shape X: (520, 17, 16) 	shape y: (520,) 	count: 37
# i: 2 	shape X: (499, 17, 16) 	shape y: (499,) 	count: 59
# i: 3 	shape X: (557, 17, 16) 	shape y: (557,) 	count: 135
# i: 4 	shape X: (509, 17, 16) 	shape y: (509,) 	count: 95
# i: 5 	shape X: (467, 17, 16) 	shape y: (467,) 	count: 90
# i: 6 	shape X: (532, 17, 16) 	shape y: (532,) 	count: 88
# i: 7 	shape X: (441, 17, 16) 	shape y: (441,) 	count: 83
# i: 8 	shape X: (491, 17, 16) 	shape y: (491,) 	count: 70
# i: 9 	shape X: (477, 17, 16) 	shape y: (477,) 	count: 74
# i: 10 	shape X: (493, 17, 16) 	shape y: (493,) 	count: 85
# i: 11 	shape X: (437, 17, 16) 	shape y: (437,) 	count: 63
# i: 12 	shape X: (467, 17, 16) 	shape y: (467,) 	count: 86
# i: 13 	shape X: (649, 17, 16) 	shape y: (649,) 	count: 57
# i: 14 	shape X: (588, 17, 16) 	shape y: (588,) 	count: 150
# i: 15 	shape X: (565, 17, 16) 	shape y: (565,) 	count: 115
# i: 16 	shape X: (541, 17, 16) 	shape y: (541,) 	count: 0
# i: 17 	shape X: (470, 17, 16) 	shape y: (470,) 	count: 77
# i: 18 	shape X: (525, 17, 16) 	shape y: (525,) 	count: 89
# i: 19 	shape X: (570, 17, 16) 	shape y: (570,) 	count: 97
# i: 20 	shape X: (489, 17, 16) 	shape y: (489,) 	count: 59
# i: 21 	shape X: (482, 17, 16) 	shape y: (482,) 	count: 76
# i: 22 	shape X: (417, 17, 16) 	shape y: (417,) 	count: 60
# -----------------------------------------------------------------------------
# shape final X: (11723, 17, 16)
# number of labeled samples: 1800

# %% [markdown]
# ### 1.3  Transform data

# %%
from keras.utils import to_categorical

X = de.X.copy()
y = de.y.copy()

print("---------------------------------------------------------------------")
print("Shapes before removal of 'no movements':") 
print("y: " + str(y.shape))
print("X: " + str(X.shape))
print("")

# only select certain indices to prevent too many 0-labeled instances
idx = []
for i in range(7):
    idx.append(np.where(np.isclose(y,i))[0])

print("Labels before removal of 'no movements'")
for i in range(7):
    print(i,len(idx[i]))
print("")
    
zero_idx = np.random.choice(idx[0], 500, replace=False)
keep_idx = np.concatenate([zero_idx,idx[1],idx[2],idx[3],idx[4],idx[5],idx[6]])
keep_idx = sorted(keep_idx)

print("---------------------------------------------------------------------")
y = y[keep_idx]
X = X[keep_idx]
print("Shapes after removal of 'no movements':") 
print("y: " + str(y.shape))
print("X: " + str(X.shape))
print("")

idx = []
for i in range(7):
    idx.append(np.where(np.isclose(y,i))[0])

print("Labels after removal of 'no movements'")
for i in range(7):
    print(i,len(idx[i]))
print("")    
    
# print("---------------------------------------------------------------------")
# print("Features:")
# print(de.LabelGenerators[0].feature_names)


print("---------------------------------------------------------------------")
gt = GestureTransformer(feature_names = list(de.LabelGenerators[0].feature_names),byrow=True)
X = gt.transform(X)

y = to_categorical(y)

print("Shapes after transformation:") 
print("y: " + str(y.shape))
print("X: " + str(X.shape))
# Out:
# ---------------------------------------------------------------------
# Shapes before removal of 'no movements':
# y: (11723,)
# X: (11723, 17, 16)
#
# Labels before removal of 'no movements'
# 0 9923
# 1 361
# 2 322
# 3 559
# 4 0
# 5 97
# 6 461
#
# ---------------------------------------------------------------------
# Shapes after removal of 'no movements':
# y: (2300,)
# X: (2300, 17, 16)
#
# Labels after removal of 'no movements'
# 0 500
# 1 361
# 2 322
# 3 559
# 4 0
# 5 97
# 6 461
#
# ---------------------------------------------------------------------
# Shapes after transformation:
# y: (2300, 7)
# X: (2300, 17, 16)

# %% [markdown]
# ## 2 Train model

# %% [markdown]
# ### 2.1  Split in train / test

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %% [markdown]
# ### 2.2 Define and compile model

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import Dropout
from keras.layers import LSTM

# %%
n_timesteps = X.shape[1] # here 17
n_features = X.shape[2] # here 16
n_outputs =  y.shape[1] # here 7 (number of labels)

model = Sequential()
model.add(LSTM(100, input_shape=(n_timesteps,n_features)))
model.add(Dropout(0.4))
model.add(Dense(100, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(n_outputs, activation='softmax'))

model.compile(loss='categorical_crossentropy', 
              optimizer='adam', 
              metrics=['accuracy'])

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 100)               46800
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                6464
# _________________________________________________________________
# dense_3 (Dense)              (None, 7)                 455
# =================================================================
# Total params: 63,819
# Trainable params: 63,819
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 2.3 Fit and validate model

# %%
history = model.fit(X_train, y_train, epochs=50, batch_size=16, verbose=1)
# Out:
# Epoch 1/50
# 1840/1840 [==============================] - 4s 2ms/step - loss: 1.1188 - acc: 0.5576
# Epoch 2/50
# 1840/1840 [==============================] - 2s 1ms/step - loss: 0.5911 - acc: 0.7766
# Epoch 3/50
# 1840/1840 [==============================] - 2s 1ms/step - loss: 0.5082 - acc: 0.8092
# Epoch 4/50
# 1840/1840 [==============================] - 2s 1ms/step - loss: 0.4665 - acc: 0.8299
# Epoch 5/50
# 1840/1840 [==============================] - 2s 1ms/step - loss: 0.4583 - acc: 0.8283
# Epoch 6/50
# 1840/1840 [==============================] - 2s 1ms/step - loss: 0.4387 - acc: 0.8375
# Epoch 7/50
# 1840/1840 [==============================] - 2s 1ms/step - loss: 0.4195 - acc: 0.8489
# Epoch 8/50
# 1840/1840 [==============================] - 2s 1ms/step - loss: 0.4310 - acc: 0.8397
# Epoch 9/50
# 1840/1840 [==============================] - 2s 1ms/step - loss: 0.4039 - acc: 0.8554
# Epoch 10/50
# 1840/1840 [==============================] - 2s 1ms/step - loss: 0.3925 - acc: 0.8522
# Epoch 11/50
# 1840/1840 [==============================] - 2s 1ms/step - loss: 0.3777 - acc: 0.8533
# Epoch 12/50
# 1840/1840 [==============================] - 2s 1ms/step - loss: 0.3547 - acc: 0.8696
# Epoch 13/50
# 1840/1840 [==============================] - 2s 1ms/step - loss: 0.3612 - acc: 0.8641
# Epoch 14/50
# 1840/1840 [==============================] - 2s 1ms/step - loss: 0.3421 - acc: 0.8750A: 1s -
# Epoch 15/50
# 1840/1840 [==============================] - 3s 2ms/step - loss: 0.3329 - acc: 0.8723
# Epoch 16/50
# 1840/1840 [==============================] - 3s 1ms/step - loss: 0.3460 - acc: 0.8707
# Epoch 17/50
# 1840/1840 [==============================] - 2s 1ms/step - loss: 0.3411 - acc: 0.8717
# Epoch 18/50
# 1840/1840 [==============================] - 3s 2ms/step - loss: 0.3379 - acc: 0.8777
# Epoch 19/50
# 1840/1840 [==============================] - 3s 1ms/step - loss: 0.3230 - acc: 0.8891A: 1s - loss: 0.335 - ETA: 0s - loss: 0.3172 - acc: 0.8
# Epoch 20/50
# 1840/1840 [==============================] - 3s 2ms/step - loss: 0.3235 - acc: 0.8799
# Epoch 21/50
# 1840/1840 [==============================] - 3s 1ms/step - loss: 0.3126 - acc: 0.8821
# Epoch 22/50
# 1840/1840 [==============================] - 3s 1ms/step - loss: 0.3058 - acc: 0.8880
# Epoch 23/50
# 1840/1840 [==============================] - 2s 1ms/step - loss: 0.2886 - acc: 0.8957
# Epoch 24/50
# 1840/1840 [==============================] - 3s 2ms/step - loss: 0.2894 - acc: 0.9005
# Epoch 25/50
# 1840/1840 [==============================] - 3s 1ms/step - loss: 0.2943 - acc: 0.8957
# Epoch 26/50
# 1840/1840 [==============================] - 3s 2ms/step - loss: 0.2936 - acc: 0.8935A
# Epoch 27/50
# 1840/1840 [==============================] - 3s 1ms/step - loss: 0.2745 - acc: 0.9005
# Epoch 28/50
# 1840/1840 [==============================] - 3s 1ms/step - loss: 0.2938 - acc: 0.8924A: 1
# Epoch 29/50
# 1840/1840 [==============================] - 3s 2ms/step - loss: 0.2825 - acc: 0.8929
# Epoch 30/50
# 1840/1840 [==============================] - 3s 2ms/step - loss: 0.2886 - acc: 0.8913
# Epoch 31/50
# 1840/1840 [==============================] - 3s 2ms/step - loss: 0.2854 - acc: 0.8962
# Epoch 32/50
# 1840/1840 [==============================] - 3s 2ms/step - loss: 0.2647 - acc: 0.9103
# Epoch 33/50
# 1840/1840 [==============================] - 3s 2ms/step - loss: 0.2752 - acc: 0.9011
# Epoch 34/50
# 1840/1840 [==============================] - 3s 1ms/step - loss: 0.2537 - acc: 0.9076
# Epoch 35/50
# 1840/1840 [==============================] - 3s 2ms/step - loss: 0.2514 - acc: 0.9103A: 1s - loss
# Epoch 36/50
# 1840/1840 [==============================] - 3s 2ms/step - loss: 0.2723 - acc: 0.8973
# Epoch 37/50
# 1840/1840 [==============================] - 3s 2ms/step - loss: 0.2562 - acc: 0.9043
# Epoch 38/50
# 1840/1840 [==============================] - 3s 2ms/step - loss: 0.2436 - acc: 0.9185
# Epoch 39/50
# 1840/1840 [==============================] - 3s 2ms/step - loss: 0.2534 - acc: 0.9054
# Epoch 40/50
# 1840/1840 [==============================] - 3s 2ms/step - loss: 0.2661 - acc: 0.9076
# Epoch 41/50
# 1840/1840 [==============================] - 3s 2ms/step - loss: 0.2390 - acc: 0.9136
# Epoch 42/50
# 1840/1840 [==============================] - 3s 2ms/step - loss: 0.2395 - acc: 0.9174
# Epoch 43/50
# 1840/1840 [==============================] - 3s 2ms/step - loss: 0.2452 - acc: 0.9098
# Epoch 44/50
# 1840/1840 [==============================] - 3s 2ms/step - loss: 0.2567 - acc: 0.9082
# Epoch 45/50
# 1840/1840 [==============================] - 3s 2ms/step - loss: 0.2580 - acc: 0.9109
# Epoch 46/50
# 1840/1840 [==============================] - 3s 2ms/step - loss: 0.2286 - acc: 0.9201A: 1s - lo
# Epoch 47/50
# 1840/1840 [==============================] - 3s 2ms/step - loss: 0.2377 - acc: 0.9174
# Epoch 48/50
# 1840/1840 [==============================] - 3s 2ms/step - loss: 0.2350 - acc: 0.9125
# Epoch 49/50
# 1840/1840 [==============================] - 4s 2ms/step - loss: 0.2250 - acc: 0.9196
# Epoch 50/50
# 1840/1840 [==============================] - 3s 2ms/step - loss: 0.2129 - acc: 0.9217

# %%
r = range(1, len(history.history["acc"]) + 1)

plt.figure(figsize=(20, 5))

plt.subplot(1, 2, 1)
plt.plot(r, history.history["acc"], label="acc")
plt.legend()
plt.title("Accuracy")

plt.subplot(1, 2, 2)
plt.plot(r, history.history["loss"], label="loss")
plt.legend()
plt.title("Loss")

plt.show()
plt.close()

# %%
eval_results = np.round(model.evaluate(X_test, y_test, batch_size=16, verbose=1),2)
print("Loss:     " + str(eval_results[0]))
print("Accuracy: " + str(eval_results[1]))
# Out:
# 460/460 [==============================] - 0s 844us/step
# Loss:     0.3
# Accuracy: 0.89

# %%
for i in range(X_test.shape[0]):
    if (model.predict_classes(X_test[i:(i+1),:,:])[0]!=np.nonzero(y_test[i])[0][0]):
        print("Index:",i,\
              "\tPred:",model.predict_classes(X_test[i:(i+1),:,:])[0],\
              "\tActual:",np.nonzero(y_test[i])[0][0],\
              "\tProbability:",round(np.max(model.predict_proba(X_test[i:(i+1),:,:])),2))
# Out:
# Index: 4 	Pred: 6 	Actual: 0 	Probability: 0.62
# Index: 6 	Pred: 3 	Actual: 0 	Probability: 0.47
# Index: 39 	Pred: 3 	Actual: 0 	Probability: 0.54
# Index: 47 	Pred: 6 	Actual: 0 	Probability: 0.64
# Index: 58 	Pred: 3 	Actual: 0 	Probability: 0.78
# Index: 65 	Pred: 5 	Actual: 1 	Probability: 0.6
# Index: 76 	Pred: 5 	Actual: 1 	Probability: 0.77
# Index: 79 	Pred: 1 	Actual: 0 	Probability: 0.99
# Index: 80 	Pred: 3 	Actual: 0 	Probability: 0.79
# Index: 91 	Pred: 2 	Actual: 0 	Probability: 0.68
# Index: 109 	Pred: 3 	Actual: 6 	Probability: 0.68
# Index: 124 	Pred: 3 	Actual: 0 	Probability: 0.82
# Index: 137 	Pred: 3 	Actual: 0 	Probability: 0.81
# Index: 152 	Pred: 0 	Actual: 3 	Probability: 0.83
# Index: 158 	Pred: 5 	Actual: 0 	Probability: 0.84
# Index: 167 	Pred: 6 	Actual: 0 	Probability: 1.0
# Index: 172 	Pred: 2 	Actual: 0 	Probability: 0.98
# Index: 175 	Pred: 1 	Actual: 5 	Probability: 0.71
# Index: 178 	Pred: 3 	Actual: 0 	Probability: 0.55
# Index: 193 	Pred: 2 	Actual: 0 	Probability: 0.89
# Index: 221 	Pred: 3 	Actual: 0 	Probability: 0.66
# Index: 234 	Pred: 3 	Actual: 0 	Probability: 0.87
# Index: 236 	Pred: 3 	Actual: 0 	Probability: 0.78
# Index: 237 	Pred: 1 	Actual: 5 	Probability: 0.84
# Index: 246 	Pred: 2 	Actual: 0 	Probability: 0.98
# Index: 249 	Pred: 3 	Actual: 0 	Probability: 0.7
# Index: 259 	Pred: 0 	Actual: 6 	Probability: 0.72
# Index: 265 	Pred: 3 	Actual: 0 	Probability: 0.98
# Index: 269 	Pred: 1 	Actual: 0 	Probability: 0.49
# Index: 278 	Pred: 5 	Actual: 1 	Probability: 0.53
# Index: 279 	Pred: 0 	Actual: 6 	Probability: 0.77
# Index: 284 	Pred: 2 	Actual: 0 	Probability: 0.99
# Index: 293 	Pred: 3 	Actual: 0 	Probability: 0.69
# Index: 310 	Pred: 3 	Actual: 0 	Probability: 0.89
# Index: 312 	Pred: 3 	Actual: 0 	Probability: 0.96
# Index: 317 	Pred: 1 	Actual: 5 	Probability: 0.93
# Index: 326 	Pred: 3 	Actual: 0 	Probability: 0.96
# Index: 329 	Pred: 0 	Actual: 3 	Probability: 0.53
# Index: 330 	Pred: 3 	Actual: 0 	Probability: 0.62
# Index: 332 	Pred: 0 	Actual: 6 	Probability: 0.87
# Index: 344 	Pred: 6 	Actual: 0 	Probability: 0.89
# Index: 363 	Pred: 0 	Actual: 3 	Probability: 0.67
# Index: 364 	Pred: 0 	Actual: 3 	Probability: 0.6
# Index: 367 	Pred: 0 	Actual: 2 	Probability: 0.93
# Index: 374 	Pred: 1 	Actual: 0 	Probability: 0.88
# Index: 404 	Pred: 3 	Actual: 0 	Probability: 0.93
# Index: 411 	Pred: 3 	Actual: 0 	Probability: 0.66
# Index: 412 	Pred: 1 	Actual: 5 	Probability: 0.73
# Index: 422 	Pred: 1 	Actual: 0 	Probability: 0.99
# Index: 436 	Pred: 0 	Actual: 3 	Probability: 0.81

# %%
for i in range(X_test.shape[0]):
    if (model.predict_classes(X_test[i:(i+1),:,:])[0]==np.nonzero(y_test[i])[0][0]):
        print("Index:",i,\
              "\tPred:",model.predict_classes(X_test[i:(i+1),:,:])[0],\
              "\tActual:",np.nonzero(y_test[i])[0][0],\
              "\tProbability:",round(np.max(model.predict_proba(X_test[i:(i+1),:,:])),2))
# Out:
# Index: 0 	Pred: 1 	Actual: 1 	Probability: 1.0
# Index: 1 	Pred: 1 	Actual: 1 	Probability: 0.99
# Index: 2 	Pred: 0 	Actual: 0 	Probability: 1.0
# Index: 3 	Pred: 3 	Actual: 3 	Probability: 0.91
# Index: 5 	Pred: 0 	Actual: 0 	Probability: 1.0
# Index: 7 	Pred: 0 	Actual: 0 	Probability: 0.73
# Index: 8 	Pred: 6 	Actual: 6 	Probability: 0.99
# Index: 9 	Pred: 2 	Actual: 2 	Probability: 0.99
# Index: 10 	Pred: 6 	Actual: 6 	Probability: 0.96
# Index: 11 	Pred: 0 	Actual: 0 	Probability: 1.0
# Index: 12 	Pred: 6 	Actual: 6 	Probability: 0.98
# Index: 13 	Pred: 6 	Actual: 6 	Probability: 0.99
# Index: 14 	Pred: 3 	Actual: 3 	Probability: 0.95
# Index: 15 	Pred: 3 	Actual: 3 	Probability: 0.95
# Index: 16 	Pred: 2 	Actual: 2 	Probability: 0.97
# Index: 17 	Pred: 1 	Actual: 1 	Probability: 0.96
# Index: 18 	Pred: 3 	Actual: 3 	Probability: 0.88
# Index: 19 	Pred: 3 	Actual: 3 	Probability: 0.93
# Index: 20 	Pred: 1 	Actual: 1 	Probability: 0.99
# Index: 21 	Pred: 3 	Actual: 3 	Probability: 0.92
# Index: 22 	Pred: 1 	Actual: 1 	Probability: 0.99
# Index: 23 	Pred: 1 	Actual: 1 	Probability: 1.0
# Index: 24 	Pred: 0 	Actual: 0 	Probability: 1.0
# Index: 25 	Pred: 1 	Actual: 1 	Probability: 1.0
# Index: 26 	Pred: 1 	Actual: 1 	Probability: 1.0
# Index: 27 	Pred: 1 	Actual: 1 	Probability: 1.0
# Index: 28 	Pred: 6 	Actual: 6 	Probability: 1.0
# Index: 29 	Pred: 3 	Actual: 3 	Probability: 0.83
# Index: 30 	Pred: 1 	Actual: 1 	Probability: 1.0
# Index: 31 	Pred: 3 	Actual: 3 	Probability: 0.88
# Index: 32 	Pred: 0 	Actual: 0 	Probability: 1.0
# Index: 33 	Pred: 6 	Actual: 6 	Probability: 0.99
# Index: 34 	Pred: 6 	Actual: 6 	Probability: 0.92
# Index: 35 	Pred: 2 	Actual: 2 	Probability: 0.98
# Index: 36 	Pred: 2 	Actual: 2 	Probability: 0.98
# Index: 37 	Pred: 6 	Actual: 6 	Probability: 0.98
# Index: 38 	Pred: 6 	Actual: 6 	Probability: 0.93
# Index: 40 	Pred: 1 	Actual: 1 	Probability: 1.0
# Index: 41 	Pred: 2 	Actual: 2 	Probability: 0.97
# Index: 42 	Pred: 6 	Actual: 6 	Probability: 0.92
# Index: 43 	Pred: 1 	Actual: 1 	Probability: 0.99
# Index: 44 	Pred: 1 	Actual: 1 	Probability: 0.87
# Index: 45 	Pred: 1 	Actual: 1 	Probability: 0.99
# Index: 46 	Pred: 6 	Actual: 6 	Probability: 0.97
# Index: 48 	Pred: 0 	Actual: 0 	Probability: 1.0
# Index: 49 	Pred: 3 	Actual: 3 	Probability: 0.94
# Index: 50 	Pred: 2 	Actual: 2 	Probability: 0.98
# Index: 51 	Pred: 0 	Actual: 0 	Probability: 1.0
# Index: 52 	Pred: 3 	Actual: 3 	Probability: 0.85
# Index: 53 	Pred: 5 	Actual: 5 	Probability: 0.84
# Index: 54 	Pred: 0 	Actual: 0 	Probability: 1.0
# Index: 55 	Pred: 3 	Actual: 3 	Probability: 0.97
# Index: 56 	Pred: 6 	Actual: 6 	Probability: 0.99
# Index: 57 	Pred: 1 	Actual: 1 	Probability: 1.0
# Index: 59 	Pred: 5 	Actual: 5 	Probability: 0.84
# Index: 60 	Pred: 2 	Actual: 2 	Probability: 0.99
# Index: 61 	Pred: 5 	Actual: 5 	Probability: 0.82
# Index: 62 	Pred: 3 	Actual: 3 	Probability: 0.52
# Index: 63 	Pred: 0 	Actual: 0 	Probability: 0.95
# Index: 64 	Pred: 1 	Actual: 1 	Probability: 1.0
# Index: 66 	Pred: 1 	Actual: 1 	Probability: 1.0
# Index: 67 	Pred: 3 	Actual: 3 	Probability: 0.97
# Index: 68 	Pred: 1 	Actual: 1 	Probability: 1.0
# Index: 69 	Pred: 2 	Actual: 2 	Probability: 0.98
# Index: 70 	Pred: 2 	Actual: 2 	Probability: 0.96
# Index: 71 	Pred: 1 	Actual: 1 	Probability: 1.0
# Index: 72 	Pred: 1 	Actual: 1 	Probability: 1.0
# Index: 73 	Pred: 3 	Actual: 3 	Probability: 0.95
# Index: 74 	Pred: 1 	Actual: 1 	Probability: 1.0
# Index: 75 	Pred: 6 	Actual: 6 	Probability: 1.0
# Index: 77 	Pred: 0 	Actual: 0 	Probability: 0.68
# Index: 78 	Pred: 0 	Actual: 0 	Probability: 1.0
# Index: 81 	Pred: 0 	Actual: 0 	Probability: 1.0
# Index: 82 	Pred: 3 	Actual: 3 	Probability: 0.95
# Index: 83 	Pred: 3 	Actual: 3 	Probability: 0.93
# Index: 84 	Pred: 6 	Actual: 6 	Probability: 0.96
# Index: 85 	Pred: 1 	Actual: 1 	Probability: 1.0
# Index: 86 	Pred: 3 	Actual: 3 	Probability: 0.92
# Index: 87 	Pred: 1 	Actual: 1 	Probability: 1.0
# Index: 88 	Pred: 3 	Actual: 3 	Probability: 0.89
# Index: 89 	Pred: 0 	Actual: 0 	Probability: 0.99
# Index: 90 	Pred: 6 	Actual: 6 	Probability: 0.98
# Index: 92 	Pred: 1 	Actual: 1 	Probability: 0.99
# Index: 93 	Pred: 3 	Actual: 3 	Probability: 0.92
# Index: 94 	Pred: 3 	Actual: 3 	Probability: 0.91
# Index: 95 	Pred: 3 	Actual: 3 	Probability: 0.94
# Index: 96 	Pred: 6 	Actual: 6 	Probability: 1.0
# Index: 97 	Pred: 3 	Actual: 3 	Probability: 0.97
# Index: 98 	Pred: 2 	Actual: 2 	Probability: 0.99
# Index: 99 	Pred: 3 	Actual: 3 	Probability: 0.93
# Index: 100 	Pred: 2 	Actual: 2 	Probability: 0.99
# Index: 101 	Pred: 3 	Actual: 3 	Probability: 0.92
# Index: 102 	Pred: 6 	Actual: 6 	Probability: 0.99
# Index: 103 	Pred: 2 	Actual: 2 	Probability: 0.97
# Index: 104 	Pred: 3 	Actual: 3 	Probability: 0.91
# Index: 105 	Pred: 6 	Actual: 6 	Probability: 0.8
# Index: 106 	Pred: 6 	Actual: 6 	Probability: 0.98
# Index: 107 	Pred: 1 	Actual: 1 	Probability: 1.0
# Index: 108 	Pred: 2 	Actual: 2 	Probability: 0.95
# Index: 110 	Pred: 2 	Actual: 2 	Probability: 0.98
# Index: 111 	Pred: 6 	Actual: 6 	Probability: 0.99
# Index: 112 	Pred: 3 	Actual: 3 	Probability: 0.7
# Index: 113 	Pred: 1 	Actual: 1 	Probability: 0.58
# Index: 114 	Pred: 3 	Actual: 3 	Probability: 0.89
# Index: 115 	Pred: 3 	Actual: 3 	Probability: 0.95
# Index:
	Pred: 2 	Actual: 2 	Probability: 0.99
# Index: 371 	Pred: 1 	Actual: 1 	Probability: 1.0
# Index: 372 	Pred: 5 	Actual: 5 	Probability: 0.61
# Index: 373 	Pred: 3 	Actual: 3 	Probability: 0.95
# Index: 375 	Pred: 3 	Actual: 3 	Probability: 0.9
# Index: 376 	Pred: 3 	Actual: 3 	Probability: 0.96
# Index: 377 	Pred: 1 	Actual: 1 	Probability: 0.99
# Index: 378 	Pred: 3 	Actual: 3 	Probability: 0.91
# Index: 379 	Pred: 6 	Actual: 6 	Probability: 0.99
# Index: 380 	Pred: 0 	Actual: 0 	Probability: 1.0
# Index: 381 	Pred: 0 	Actual: 0 	Probability: 1.0
# Index: 382 	Pred: 2 	Actual: 2 	Probability: 0.98
# Index: 383 	Pred: 2 	Actual: 2 	Probability: 0.98
# Index: 384 	Pred: 6 	Actual: 6 	Probability: 0.99
# Index: 385 	Pred: 6 	Actual: 6 	Probability: 0.99
# Index: 386 	Pred: 3 	Actual: 3 	Probability: 0.91
# Index: 387 	Pred: 0 	Actual: 0 	Probability: 1.0
# Index: 388 	Pred: 3 	Actual: 3 	Probability: 0.93
# Index: 389 	Pred: 6 	Actual: 6 	Probability: 0.97
# Index: 390 	Pred: 6 	Actual: 6 	Probability: 0.99
# Index: 391 	Pred: 2 	Actual: 2 	Probability: 0.94
# Index: 392 	Pred: 1 	Actual: 1 	Probability: 1.0
# Index: 393 	Pred: 3 	Actual: 3 	Probability: 0.96
# Index: 394 	Pred: 1 	Actual: 1 	Probability: 0.94
# Index: 395 	Pred: 5 	Actual: 5 	Probability: 0.59
# Index: 396 	Pred: 1 	Actual: 1 	Probability: 1.0
# Index: 397 	Pred: 0 	Actual: 0 	Probability: 0.89
# Index: 398 	Pred: 2 	Actual: 2 	Probability: 0.96
# Index: 399 	Pred: 6 	Actual: 6 	Probability: 0.99
# Index: 400 	Pred: 6 	Actual: 6 	Probability: 0.95
# Index: 401 	Pred: 2 	Actual: 2 	Probability: 0.99
# Index: 402 	Pred: 0 	Actual: 0 	Probability: 1.0
# Index: 403 	Pred: 1 	Actual: 1 	Probability: 1.0
# Index: 405 	Pred: 1 	Actual: 1 	Probability: 1.0
# Index: 406 	Pred: 1 	Actual: 1 	Probability: 1.0
# Index: 407 	Pred: 3 	Actual: 3 	Probability: 0.9
# Index: 408 	Pred: 6 	Actual: 6 	Probability: 0.99
# Index: 409 	Pred: 0 	Actual: 0 	Probability: 1.0
# Index: 410 	Pred: 3 	Actual: 3 	Probability: 0.86
# Index: 413 	Pred: 2 	Actual: 2 	Probability: 0.98
# Index: 414 	Pred: 3 	Actual: 3 	Probability: 0.87
# Index: 415 	Pred: 6 	Actual: 6 	Probability: 0.95
# Index: 416 	Pred: 2 	Actual: 2 	Probability: 0.97
# Index: 417 	Pred: 0 	Actual: 0 	Probability: 0.64
# Index: 418 	Pred: 2 	Actual: 2 	Probability: 0.99
# Index: 419 	Pred: 6 	Actual: 6 	Probability: 0.94
# Index: 420 	Pred: 2 	Actual: 2 	Probability: 0.98
# Index: 421 	Pred: 6 	Actual: 6 	Probability: 0.99
# Index: 423 	Pred: 6 	Actual: 6 	Probability: 1.0
# Index: 424 	Pred: 6 	Actual: 6 	Probability: 1.0
# Index: 425 	Pred: 6 	Actual: 6 	Probability: 0.99
# Index: 426 	Pred: 1 	Actual: 1 	Probability: 1.0
# Index: 427 	Pred: 6 	Actual: 6 	Probability: 1.0
# Index: 428 	Pred: 6 	Actual: 6 	Probability: 0.89
# Index: 429 	Pred: 1 	Actual: 1 	Probability: 1.0
# Index: 430 	Pred: 3 	Actual: 3 	Probability: 0.72
# Index: 431 	Pred: 3 	Actual: 3 	Probability: 0.97
# Index: 432 	Pred: 0 	Actual: 0 	Probability: 1.0
# Index: 433 	Pred: 6 	Actual: 6 	Probability: 0.87
# Index: 434 	Pred: 2 	Actual: 2 	Probability: 0.98
# Index: 435 	Pred: 6 	Actual: 6 	Probability: 0.67
# Index: 437 	Pred: 6 	Actual: 6 	Probability: 0.96
# Index: 438 	Pred: 1 	Actual: 1 	Probability: 0.99
# Index: 439 	Pred: 3 	Actual: 3 	Probability: 0.93
# Index: 440 	Pred: 0 	Actual: 0 	Probability: 1.0
# Index: 441 	Pred: 1 	Actual: 1 	Probability: 1.0
# Index: 442 	Pred: 1 	Actual: 1 	Probability: 1.0
# Index: 443 	Pred: 2 	Actual: 2 	Probability: 0.98
# Index: 444 	Pred: 0 	Actual: 0 	Probability: 1.0
# Index: 445 	Pred: 3 	Actual: 3 	Probability: 0.95
# Index: 446 	Pred: 2 	Actual: 2 	Probability: 0.99
# Index: 447 	Pred: 0 	Actual: 0 	Probability: 0.77
# Index: 448 	Pred: 6 	Actual: 6 	Probability: 0.88
# Index: 449 	Pred: 1 	Actual: 1 	Probability: 1.0
# Index: 450 	Pred: 6 	Actual: 6 	Probability: 1.0
# Index: 451 	Pred: 1 	Actual: 1 	Probability: 1.0
# Index: 452 	Pred: 3 	Actual: 3 	Probability: 0.91
# Index: 453 	Pred: 6 	Actual: 6 	Probability: 0.94
# Index: 454 	Pred: 6 	Actual: 6 	Probability: 0.97
# Index: 455 	Pred: 1 	Actual: 1 	Probability: 0.91
# Index: 456 	Pred: 3 	Actual: 3 	Probability: 0.82
# Index: 457 	Pred: 1 	Actual: 1 	Probability: 1.0
# Index: 458 	Pred: 3 	Actual: 3 	Probability: 0.92
# Index: 459 	Pred: 0 	Actual: 0 	Probability: 1.0

# %% [markdown]
# ### 2.4 Save model

# %%
from keras.models import load_model
import h5py

# %%
# save model, delete current reference and re-load it from file
model.save('model_gesture.h5')
del model
model = load_model('../model_gesture.h5')

# %%
type(model)
# Out:
# keras.engine.sequential.Sequential
